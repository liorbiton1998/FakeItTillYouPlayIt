# %% [markdown]
# # Import Required Libraries

# %%
# !pip install google-generativeai
import google.generativeai as genai
import os
import subprocess
import time
import pandas as pd
from google import genai
from google.genai import types

# Set up API key
genai.configure(api_key="---")

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.24.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.160.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.25.6)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.10.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.68.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (2.27.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2025.1.31)

# %% [markdown]
# # Classification Using Gemini

# %%
# Define directories
BASE_DOWNLOAD_DIR = "/content/drive/My Drive/Youtube_Game_Ads/Videos"
PROCESSED_RESPONSES_DIR = "/content/drive/My Drive/Youtube_Game_Ads/Processed_Responses"
os.makedirs(PROCESSED_RESPONSES_DIR, exist_ok=True)

# Initialize Google Gemini AI client
client = genai.Client(api_key="AIzaSyDY5QjBID09gIfTwZDruPpwJVyIF3mC3BM")

# Define classification categories
CATEGORIES = [
    "Bait-and-Switch",
    "Fake Incompetence",
    "Emotional Manipulation",
    "Sexualized Clickbait",
    "False Storylines",
    "Borrowed IP",
    "Exaggerated Difficulty"
]

# Find all MP4 videos
video_files = []
for root, _, files in os.walk(BASE_DOWNLOAD_DIR):
    for file in files:
        if file.endswith(".mp4"):
            video_files.append(os.path.join(root, file))

# Path for the CSV file
csv_output_path = os.path.join(PROCESSED_RESPONSES_DIR, "gemini_analysis_results.csv")
if not os.path.exists(csv_output_path):
    df_results = pd.DataFrame(columns=["Video"] + CATEGORIES)
    df_results.to_csv(csv_output_path, index=False, encoding="utf-8")

print(f"Processing {len(video_files)} videos...")

for i, video in enumerate(video_files):
    print(f"\nProcessing Video {i+1}/{len(video_files)}: {video}")

    # Create a temporary file for the trimmed video
    temp_video_path = f"/tmp/trimmed_{i}.mp4"

    # Use ffmpeg to trim the first 10 seconds and save it to the temporary file
    ffmpeg_command = [
        "ffmpeg",
        "-i", video,      # Input file
        "-t", "10",       # Cut duration (10 seconds)
        "-c:v", "libx264", "-crf", "23", "-preset", "fast", # Video encoding
        "-c:a", "aac", "-b:a", "128k",  # Audio encoding
        temp_video_path  # Output file
    ]
    subprocess.run(ffmpeg_command, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    print(f"Trimmed video temporarily saved: {temp_video_path}")

    # Upload trimmed video to Gemini
    uploaded_file = client.files.upload(file=temp_video_path)
    os.remove(temp_video_path)
    print("Temporary video deleted after upload.")

    # Wait for file to become ACTIVE
    file_id = uploaded_file.name
    max_retries = 10
    sleep_time = 5
    for attempt in range(max_retries):
        file_status = client.files.get(name=file_id).state
        print(f"Checking file status ({attempt + 1}/{max_retries}): {file_status}")

        if file_status == "ACTIVE":
            print("File is ACTIVE. Proceeding with analysis.")
            break
        else:
            print(f"File not ready yet. Waiting {sleep_time} seconds...")
            time.sleep(sleep_time)
    else:
        print("File did not become ACTIVE. Skipping this video.")
        continue

    # Define prompt for Gemini AI
    prompt = types.Content(
        role="user",
        parts=[
            types.Part.from_uri(
                file_uri=uploaded_file.uri,
                mime_type=uploaded_file.mime_type,
            ),
            types.Part.from_text(
                text="""Analyze this mobile game ad and classify it based on the following characteristics:

Bait-and-Switch (fake gameplay or features not in the real game)
Fake Incompetence (character fails on purpose to make viewers want to try)
Emotional Manipulation (uses drama, urgency, or distress to get attention)
Sexualized Clickbait (provocative visuals or suggestive situations)
False Storylines (storytelling that does not exist in the actual game)
Borrowed IP (uses famous characters, brands, or styles not in the game)
Exaggerated Difficulty (claims the game is super hard when it's easy)

List only the categories that apply to this ad and provide a short explanation for each."""
            ),
        ],
    )

    # Generate content from Gemini AI
    response_text = ""
    for chunk in client.models.generate_content_stream(
        model="gemini-2.0-flash",
        contents=[prompt],
        config=types.GenerateContentConfig(
            temperature=1,
            top_p=0.95,
            top_k=40,
            max_output_tokens=8192,
            response_mime_type="text/plain",
        ),
    ):
        response_text += chunk.text

    print("Response received from Gemini AI.")

    # Parse response for classification
    response_dict = {"Video": video}
    for category in CATEGORIES:
        if category in response_text:
            start_index = response_text.find(category) + len(category) + 1
            end_index = response_text.find("\n", start_index)
            response_dict[category] = response_text[start_index:end_index].strip()
        else:
            response_dict[category] = ""

    # Append the response to the CSV
    df_results = pd.DataFrame([response_dict])
    df_results.to_csv(csv_output_path, mode="a", header=False, index=False, encoding="utf-8")

    print(f"Response saved to CSV: {csv_output_path}")

print(f"\nAll videos analyzed and results saved to: {csv_output_path}")
# Out:
# Processing 250 videos...
#
# Processing Video 1/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars Mighty Party Latest Mobile Game Ads '241' Win LOVE HELP 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_0.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 2/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '450' Shark attacking raft sleeping hero.mp4
# Trimmed video temporarily saved: /tmp/trimmed_1.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 3/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party, Hero Wars, Hero Rescue mobile games ads collection #53 Get treasure chest.mp4
# Trimmed video temporarily saved: /tmp/trimmed_2.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 4/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars Mighty Party Latest Mobile Game Ads '238' Bell LOVE HELP 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_3.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 5/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '394' Hero Transformation in Prison Break attempt.mp4
# Trimmed video temporarily saved: /tmp/trimmed_4.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 6/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars mobile games ads '128' HELP!.mp4
# Trimmed video temporarily saved: /tmp/trimmed_5.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 7/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars Mighty Party Hero Castle Wars Mobile Games Ads '230' Love meter 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_6.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 8/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '417' Stone Gold Miner Dig.mp4
# Trimmed video temporarily saved: /tmp/trimmed_7.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 9/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars Mobile Games Ads '182' Kick HELP Love 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_8.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 10/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars mobile games ads '98' Choking LOVE HELP 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_9.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 11/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Wars Mobile Game Ads '179' Underwater Bubble Takeover HELP Love 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_10.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 12/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars latest mobile game ads '359' Super Stickman Fight.mp4
# Trimmed video temporarily saved: /tmp/trimmed_11.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 13/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars latest game ads '108' only Math can save her! LOVE HELP! 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_12.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 14/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '407' Pathetic Pit takeover failed Spartan.mp4
# Trimmed video temporarily saved: /tmp/trimmed_13.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 15/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars Mobile Games Ads '213' Girl whipping Girl LOVE HELP 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_14.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 16/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Wars latest mobile game ads '256' Save Treasure on Net.mp4
# Trimmed video temporarily saved: /tmp/trimmed_15.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 17/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Wars latest mobile game ads '251' Rail Track Takeover LOVE HELP 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_16.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 18/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars latest game ads '301' Underwater Fight like Fishdom.mp4
# Trimmed video temporarily saved: /tmp/trimmed_17.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 19/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars mobile games ads '95' Multi Maze 3D LOVE HELP! 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_18.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 20/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '494' weird ads.mp4
# Trimmed video temporarily saved: /tmp/trimmed_19.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 21/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars Mobile Games Ads '162' Bowmasters Multiplayer.mp4
# Trimmed video temporarily saved: /tmp/trimmed_20.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 22/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads shorts '440' Fall from Dragon's Mouth.mp4
# Trimmed video temporarily saved: /tmp/trimmed_21.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 23/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '386' Become a Legend.mp4
# Trimmed video temporarily saved: /tmp/trimmed_22.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 24/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars Mobile Games Ads '175' Running from enemy to rescue princess HELP.mp4
# Trimmed video temporarily saved: /tmp/trimmed_23.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 25/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero wars mobile game ads '556' babes.mp4
# Trimmed video temporarily saved: /tmp/trimmed_24.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 26/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '510'.mp4
# Trimmed video temporarily saved: /tmp/trimmed_25.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 27/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '485' Zeus being god of sea.mp4
# Trimmed video temporarily saved: /tmp/trimmed_26.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 28/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Wars latest mobile game ads '257' Mob Control Rescue Princess LOVE HELP 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_27.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 29/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '486' Tower Defense Dragon Fire.mp4
# Trimmed video temporarily saved: /tmp/trimmed_28.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 30/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars Mobile Games Ads '214' Monster Pushing to Lava HELP!.mp4
# Trimmed video temporarily saved: /tmp/trimmed_29.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 31/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Wars latest mobile game ads '247' Stone & Net LOVE HELP 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_30.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 32/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars mobile games ads '101' Win & Reveal dress LOVE HELP 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_31.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 33/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '544' Rescue Mission like Fishdom.mp4
# Trimmed video temporarily saved: /tmp/trimmed_32.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 34/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '391' Arrow path Dig.mp4
# Trimmed video temporarily saved: /tmp/trimmed_33.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 35/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars Latest Mobile Game Ads '277' SAVE princess LOVE HELP!.mp4
# Trimmed video temporarily saved: /tmp/trimmed_34.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 36/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero wars mobile game ads '559' Rescue Princesses.mp4
# Trimmed video temporarily saved: /tmp/trimmed_35.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 37/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads shorts '447' Hero Falling into Mud from Tower.mp4
# Trimmed video temporarily saved: /tmp/trimmed_36.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 38/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars mobile games ads '123' Save the Princess LOVE HELP 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_37.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 39/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '482' Tower Takeover underwater key chest.mp4
# Trimmed video temporarily saved: /tmp/trimmed_38.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 40/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Wars Latest Mobile Game Ads '263' Monster choking Lady LOVE HELP 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_39.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 41/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '499' You will never win.mp4
# Trimmed video temporarily saved: /tmp/trimmed_40.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 42/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '507' Her ex vs You.mp4
# Trimmed video temporarily saved: /tmp/trimmed_41.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 43/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '483' Dungeons explore.mp4
# Trimmed video temporarily saved: /tmp/trimmed_42.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 44/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars mobile games ads '132' Oh My Goodness LOVE HELP 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_43.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 45/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Wars latest mobile game ads '264' Stair Takeover LOVE HELP 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_44.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 46/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars mobile games ads '114' Break blocks LOVE HELP 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_45.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 47/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars latest mobile game ads '334' Red Toilet appears in Train.mp4
# Trimmed video temporarily saved: /tmp/trimmed_46.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 48/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Mighty Party Hero Rescue Hero Wars Mobile Games Ads '227' Puzzle.mp4
# Trimmed video temporarily saved: /tmp/trimmed_47.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 49/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars mobile game ads '406' Super Stickman Tower Takeover Giant Huggy Wuggy Plushy Poppy.mp4
# Trimmed video temporarily saved: /tmp/trimmed_48.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 50/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Hero_Wars/Hero Wars latest mobile game ads '290' Evil Mermaid Kidnapped Child.mp4
# Trimmed video temporarily saved: /tmp/trimmed_49.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 51/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/
mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 233/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '91' Toilet Emergency in Train.mp4
# Trimmed video temporarily saved: /tmp/trimmed_232.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 234/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '13' Kissing in Train 16+.mp4
# Trimmed video temporarily saved: /tmp/trimmed_233.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 235/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '196' Table Tennis.mp4
# Trimmed video temporarily saved: /tmp/trimmed_234.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 236/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '26' Save the Girlfriend.mp4
# Trimmed video temporarily saved: /tmp/trimmed_235.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 237/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '148'.mp4
# Trimmed video temporarily saved: /tmp/trimmed_236.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 238/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '138' Underwater fight with zombies.mp4
# Trimmed video temporarily saved: /tmp/trimmed_237.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 239/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads shorts '100' Joker Doctor Zombie Attack in Hospital.mp4
# Trimmed video temporarily saved: /tmp/trimmed_238.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 240/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '202' Swimming Practice.mp4
# Trimmed video temporarily saved: /tmp/trimmed_239.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 241/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '177' zombies in train.mp4
# Trimmed video temporarily saved: /tmp/trimmed_240.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 242/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '9'.mp4
# Trimmed video temporarily saved: /tmp/trimmed_241.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 243/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '54' Lady with Katana.mp4
# Trimmed video temporarily saved: /tmp/trimmed_242.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 244/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '185'.mp4
# Trimmed video temporarily saved: /tmp/trimmed_243.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 245/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '240' Zombie Shooting training.mp4
# Trimmed video temporarily saved: /tmp/trimmed_244.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 246/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '211' Rat caught.mp4
# Trimmed video temporarily saved: /tmp/trimmed_245.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 247/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '88' Fart in elevator line, Zombie Attack.mp4
# Trimmed video temporarily saved: /tmp/trimmed_246.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 248/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '184'.mp4
# Trimmed video temporarily saved: /tmp/trimmed_247.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 249/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '82' Zombie Attack at Golf Practice.mp4
# Trimmed video temporarily saved: /tmp/trimmed_248.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# Processing Video 250/250: /content/drive/My Drive/Youtube_Game_Ads/Videos/Puzzles_and_Survival/Puzzles and Survival game ads '62' Zombie Attack on Train, Immortal Joe to the Rescue.mp4
# Trimmed video temporarily saved: /tmp/trimmed_249.mp4
# Temporary video deleted after upload.
# Checking file status (1/10): FileState.PROCESSING
# File not ready yet. Waiting 5 seconds...
# Checking file status (2/10): FileState.ACTIVE
# File is ACTIVE. Proceeding with analysis.
# Response received from Gemini AI.
# Response saved to CSV: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
#
# All videos analyzed and results saved to: /content/drive/My Drive/Youtube_Game_Ads/Processed_Responses/gemini_analysis_results.csv
